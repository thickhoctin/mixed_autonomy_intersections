# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load results
df = pd.read_csv('results/twoway_2x1_penetration0.1/train_results.csv')

# %%
# Raw Reward
plt.figure(figsize=(10, 6))
plt.plot(df['step'], df['raw_reward_mean'])
plt.title('Raw Reward Mean')
plt.xlabel('Training Step')
plt.ylabel('Reward')
plt.grid(True)
plt.show()

# %%
# Speed
plt.figure(figsize=(10, 6))
plt.plot(df['step'], df['speed'], label='All vehicles', linewidth=2)
plt.plot(df['step'], df['speed_rl'], label='RL vehicles', linewidth=2)
plt.title('Speed Over Training')
plt.xlabel('Training Step')
plt.ylabel('Speed (m/s)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Collisions
plt.figure(figsize=(10, 6))
plt.plot(df['step'], df['collisions'], color='red')
plt.title('Collisions')
plt.xlabel('Training Step')
plt.ylabel('Number of Collisions')
plt.grid(True)
plt.show()

# %%
# Throughput
plt.figure(figsize=(10, 6))
plt.plot(df['step'], df['outflow_hourly'], color='green')
plt.title('Outflow (Throughput)')
plt.xlabel('Training Step')
plt.ylabel('Vehicles per Hour')
plt.grid(True)
plt.show()

# %%
# Policy Loss
plt.figure(figsize=(10, 6))
plt.plot(df['step'], df['policy_loss'], color='purple')
plt.title('Policy Loss')
plt.xlabel('Training Step')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %%
# Load results
df = pd.read_csv('results/fourway_1x1_penetration0.5_turn_adam_ppo_06.12/train_results.csv')
grm = df.get('global_reward_mean')
# Global Reward Mean
print("Maximum Global Reward Mean:", grm.max())
print('step', df.loc[grm.idxmax()]['step'])
# Thoughput
print("Maximum Outflow:", df['outflow_hourly'].max())
print('step', df.loc[df['outflow_hourly'].idxmax()]['step'])
# Collisions at step of maximum global reward
print('Collision at step', df.loc[grm.idxmax()]['step'], 'is', df.loc[grm.idxmax()]['collisions'])
print('Collision at step', df.loc[df['outflow_hourly'].idxmax()]['step'], 'is', df.loc[df['outflow_hourly'].idxmax()]['collisions'])
# Out:
# Maximum Global Reward Mean: 0.156667
# step 158.0
# Maximum Outflow: 1937.7
# step 107.0
# Collision at step 158.0 is 9.75
# Collision at step 107.0 is 13.1667

# %%
# Load results
df = pd.read_csv('results/fourway_1x1_penetration0.5_turn_adam_ppo_17.12/train_results.csv')
grm = df.get('global_reward_mean')
# Global Reward Mean
print("Maximum Global Reward Mean:", grm.max())
print('step', df.loc[grm.idxmax()]['step'])
# Thoughput
print("Maximum Outflow:", df['outflow_hourly'].max())
print('step', df.loc[df['outflow_hourly'].idxmax()]['step'])
# Collisions at step of maximum global reward
print('Collision at step', df.loc[grm.idxmax()]['step'], 'is', df.loc[grm.idxmax()]['collisions'])
print('Collision at step', df.loc[df['outflow_hourly'].idxmax()]['step'], 'is', df.loc[df['outflow_hourly'].idxmax()]['collisions'])
# Out:
# Maximum Global Reward Mean: 0.120356
# step 113.0
# Maximum Outflow: 1799.66
# step 282.0
# Collision at step 113.0 is 1.3125
# Collision at step 282.0 is 4.1875
